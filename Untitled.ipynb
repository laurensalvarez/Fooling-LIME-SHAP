# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("treedump.csv")

# %%
df.head()
# Out:
#    Age_uid  Age_hi  Age_lo        Age_m2     Age_mu  Age_n     Age_sd  \
# 0        1      70      18  33113.863874  35.230366    191  13.201647
# 1        1      70      17  35883.591623  34.471204    191  13.742671
# 2        1      70      17  31885.183246  33.141361    191  12.954411
# 3        1      70      17  37062.198953  34.214660    191  13.966539
# 4        1      70      17  35837.811518  34.031414    191  13.733902
#
#    Education-num_uid  Education-num_hi  Education-num_lo  ...  \
# 0                  2                16                 4  ...
# 1                  2                16                 1  ...
# 2                  2                16                 2  ...
# 3                  2                16                 1  ...
# 4                  2                16                 1  ...
#
#    Hours-per-week_lo  Hours-per-week_m2  Hours-per-week_mu  Hours-per-week_n  \
# 0                  8       30960.743455          41.036649               191
# ...

# %%
df.columns
# Out:
# Index(['Age_uid', 'Age_hi', 'Age_lo', 'Age_m2', 'Age_mu', 'Age_n', 'Age_sd',
#        'Education-num_uid', 'Education-num_hi', 'Education-num_lo',
#        'Education-num_m2', 'Education-num_mu', 'Education-num_n',
#        'Education-num_sd', 'race_uid', 'race_mode', 'race_most', 'race_n',
#        'sex_uid', 'sex_mode', 'sex_most', 'sex_n', 'Capital-gain_uid',
#        'Capital-gain_hi', 'Capital-gain_lo', 'Capital-gain_m2',
#        'Capital-gain_mu', 'Capital-gain_n', 'Capital-gain_sd',
#        'Capital-loss_uid', 'Capital-loss_hi', 'Capital-loss_lo',
#        'Capital-loss_m2', 'Capital-loss_mu', 'Capital-loss_n',
#        'Capital-loss_sd', 'Hours-per-week_uid', 'Hours-per-week_hi',
#        'Hours-per-week_lo', 'Hours-per-week_m2', 'Hours-per-week_mu',
#        'Hours-per-week_n', 'Hours-per-week_sd', 'probability!_uid',
#        'probability!_mode', 'probability!_most', 'probability!_n',
#        'Unnamed: 47'],
#       dtype='object')

# %%
len(df)
# Out:
# 256
